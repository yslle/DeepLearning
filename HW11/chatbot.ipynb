# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Example dataset
conversations = [
 ["Hello", "Hi there!"],
 ["How are you?", "I'm doing well, thanks."],
 ["What's your name?", "I'm a chatbot."]
]
token = Tokenizer()
token.fit_on_texts(conversations)
print(token.word_index)

sequences = token.texts_to_sequences(conversations)
print(sequences)

user_input = 'How are you?'
input_seq = token.texts_to_sequences([user_input])
print("Input Seq: ", input_seq)
exit(0)

max_sequence_len = max([len(seq) for seq in sequences])
print("Max Input Len: ", max_sequence_len)

print("==================: ", len(sequences))
X = []; y = []
for idx in range(len(sequences)):
  X.append([sequences[idx][0]])
  y.append([sequences[idx][1]])
print(X)
print(y)
word_size = len(token.word_index) + 1
print("Size: ", word_size)

# 모델의 설정
model = Sequential()
model.add( Embedding(word_size, 64, input_length=max_sequence_len, mask_zero=True) )
model.add( LSTM(100, return_sequences=True) )
model.add( Dense(word_size, activation='softmax') )

# 모델의 컴파일
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(X, y, epochs=50, verbose=1)

def generate_response(input_text):
  input_seq = token.texts_to_sequences([[input_text]])
  print("input seq: ", input_seq)
  predicted_output = model.predict(input_seq)
  print("Predict Output: ", predicted_output)

  predicted_word_index = tf.argmax(predicted_output, axis=-1).numpy()
  print("Predict Index: ", predicted_word_index)
  response = token.sequences_to_texts(predicted_word_index)
  return response[0]

# Test the chatbot
user_input = "how are you?"
response = generate_response(user_input)
print(f"User: {user_input}")
print(f"Chatbot: {response}")
# Out:
# {'hello': 1, 'hi there!': 2, 'how are you?': 3, "i'm doing well, thanks.": 4, "what's your name?": 5, "i'm a chatbot.": 6}
# [[1, 2], [3, 4], [5, 6]]
# Input Seq:  [[]]
# Max Input Len:  2
# ==================:  3
# [[1], [3], [5]]
# [[2], [4], [6]]
# Size:  7
# Epoch 1/50
# 1/1 [==============================] - 5s 5s/step - loss: 1.9484 - accuracy: 0.0000e+00
# Epoch 2/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.9419 - accuracy: 0.3333
# Epoch 3/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.9354 - accuracy: 1.0000
# Epoch 4/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.9290 - accuracy: 1.0000
# Epoch 5/50
# 1/1 [==============================] - 0s 19ms/step - loss: 1.9224 - accuracy: 1.0000
# Epoch 6/50
# 1/1 [==============================] - 0s 15ms/step - loss: 1.9159 - accuracy: 1.0000
# Epoch 7/50
# 1/1 [==============================] - 0s 15ms/step - loss: 1.9093 - accuracy: 1.0000
# Epoch 8/50
# 1/1 [==============================] - 0s 17ms/step - loss: 1.9025 - accuracy: 1.0000
# Epoch 9/50
# 1/1 [==============================] - 0s 17ms/step - loss: 1.8956 - accuracy: 1.0000
# Epoch 10/50
# 1/1 [==============================] - 0s 19ms/step - loss: 1.8886 - accuracy: 1.0000
# Epoch 11/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.8813 - accuracy: 1.0000
# Epoch 12/50
# 1/1 [==============================] - 0s 20ms/step - loss: 1.8738 - accuracy: 1.0000
# Epoch 13/50
# 1/1 [==============================] - 0s 19ms/step - loss: 1.8661 - accuracy: 1.0000
# Epoch 14/50
# 1/1 [==============================] - 0s 22ms/step - loss: 1.8581 - accuracy: 1.0000
# Epoch 15/50
# 1/1 [==============================] - 0s 20ms/step - loss: 1.8498 - accuracy: 1.0000
# Epoch 16/50
# 1/1 [==============================] - 0s 22ms/step - loss: 1.8411 - accuracy: 1.0000
# Epoch 17/50
# 1/1 [==============================] - 0s 19ms/step - loss: 1.8321 - accuracy: 1.0000
# Epoch 18/50
# 1/1 [==============================] - 0s 17ms/step - loss: 1.8227 - accuracy: 1.0000
# Epoch 19/50
# 1/1 [==============================] - 0s 19ms/step - loss: 1.8129 - accuracy: 1.0000
# Epoch 20/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.8026 - accuracy: 1.0000
# Epoch 21/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1.7919 - accuracy: 1.0000
# Epoch 22/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.7807 - accuracy: 1.0000
# Epoch 23/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.7690 - accuracy: 1.0000
# Epoch 24/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.7567 - accuracy: 1.0000
# Epoch 25/50
# 1/1 [==============================] - 0s 21ms/step - loss: 1.7439 - accuracy: 1.0000
# Epoch 26/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1.7305 - accuracy: 1.0000
# Epoch 27/50
# 1/1 [==============================] - 0s 15ms/step - loss: 1.7165 - accuracy: 1.0000
# Epoch 28/50
# 1/1 [==============================] - 0s 15ms/step - loss: 1.7019 - accuracy: 1.0000
# Epoch 29/50
# 1/1 [==============================] - 0s 22ms/step - loss: 1.6865 - accuracy: 1.0000
# Epoch 30/50
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6705 - accuracy: 1.0000
# Epoch 31/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.6537 - accuracy: 1.0000
# Epoch 32/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.6362 - accuracy: 1.0000
# Epoch 33/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.6180 - accuracy: 1.0000
# Epoch 34/50
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5989 - accuracy: 1.0000
# Epoch 35/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.5789 - accuracy: 1.0000
# Epoch 36/50
# 1/1 [==============================] - 0s 12ms/step - loss: 1.5582 - accuracy: 1.0000
# Epoch 37/50
# 1/1 [==============================] - 0s 23ms/step - loss: 1.5365 - accuracy: 1.0000
# Epoch 38/50
# 1/1 [==============================] - 0s 19ms/step - loss: 1.5139 - accuracy: 1.0000
# Epoch 39/50
# 1/1 [==============================] - 0s 15ms/step - loss: 1.4904 - accuracy: 1.0000
# Epoch 40/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.4659 - accuracy: 1.0000
# Epoch 41/50
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4405 - accuracy: 1.0000
# Epoch 42/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4141 - accuracy: 1.0000
# Epoch 43/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1.3866 - accuracy: 1.0000
# Epoch 44/50
# 1/1 [==============================] - 0s 20ms/step - loss: 1.3582 - accuracy: 1.0000
# Epoch 45/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1.3288 - accuracy: 1.0000
# Epoch 46/50
# 1/1 [==============================] - 0s 19ms/step - loss: 1.2983 - accuracy: 1.0000
# Epoch 47/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.2668 - accuracy: 1.0000
# Epoch 48/50
# 1/1 [==============================] - 0s 13ms/step - loss: 1.2344 - accuracy: 1.0000
# Epoch 49/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1.2009 - accuracy: 1.0000
# Epoch 50/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.1666 - accuracy: 1.0000
# input seq:  [[3]]
# 1/1 [==============================] - 1s 1s/step
# Predict Output:  [[[0.1036343  0.09686843 0.14839494 0.09731966 0.3061382  0.09633213
#    0.15131234]]]
# Predict Index:  [[4]]
# User: how are you?
# Chatbot: i'm doing well, thanks.
